# %% [markdown]
# ### Check Code Data Preprocessing

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/root/MIMICIV/src/mimiciv_clinical_dataset_tabular_death_visit.csv")
df2 = pd.read_csv("/root/MIMICIV/src/mimiciv_clinical_dataset_tabular_death_visit_2.csv")

# %%
df1.equals(df2)
# Out:
# True

# %% [markdown]
# Then /root/MIMICIV/src/mimiciv_clinical_dataset_tabular_death_visit.csv has been created using the tabular.py script. Let's go further and see how the dataset landmark_df.csv has been created.

# %%
# Importing libraries (exactly as from xgboost.ipynb)
import ast
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sp

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from scipy.sparse import hstack

# %%
# Load dataset
df = pd.read_csv("mimiciv_clinical_dataset_tabular_death_visit.csv")

# Count admission categories
admission_counts = df['admission_category'].value_counts()

# Display counts
print("Admission category counts:")
print(admission_counts := df['admission_category'].value_counts())
# Out:
# Admission category counts:
# admission_category
# NORMAL       291667
# EMERGENCY    254361
# Name: count, dtype: int64

# %%
def safe_join(x):
    if pd.isna(x) or x in ['[]', '', 'None', 'NaN', 'na', 'nan']:
        return ''
    try:
        x_eval = ast.literal_eval(x)
        if isinstance(x_eval, list):
            return '; '.join(x_eval)
        else:
            return ''
    except:
        return ''

landmark_rows = []

#df = df.sort_values(['subject_id', 'hadm_id']).reset_index(drop=True) # That's not the right ordering!
# the dataset is still ordered, however we should consider a more robust way of doing so.

# %%
for patient_id, group in df.groupby('subject_id'):
    group = group.reset_index(drop=True)
    n_visits = group.shape[0]

    for landmark_idx in range(n_visits):
        current_visit = group.iloc[landmark_idx]
        past_visits = group.iloc[:landmark_idx + 1]

        # Here: to be more efficient - how to say confirmed/new? For now okay here

        unique_vals = set(past_visits['medication_list'])
        if len(unique_vals) == 1 and pd.isna(next(iter(unique_vals))):
            meds_text = ''
        else:
            meds_text = ' '.join(past_visits['medication_list'].apply(safe_join))
        
        unique_vals = set(past_visits['diagnosis_list'])
        if len(unique_vals) == 1 and pd.isna(next(iter(unique_vals))):
            diag_text = ''
        else:
            diag_text = ' '.join(past_visits['diagnosis_list'].apply(safe_join))
        
        unique_vals = set(past_visits['procedure_list'])
        if len(unique_vals) == 1 and pd.isna(next(iter(unique_vals))):
            proc_text = ''
        else:
            proc_text = ' '.join(past_visits['procedure_list'].apply(safe_join))

        # Define outcome
        days_to_death = current_visit['days_from_last_visit_to_death']
        death_in_90days = 1 if (not np.isnan(days_to_death) and days_to_death <= 90) else 0

        landmark_rows.append({
            'subject_id': current_visit['subject_id'],
            'landmark_visit': landmark_idx + 1,
            'age_at_landmark': current_visit['age_at_event'],
            'gender': current_visit['gender'],
            'num_total_visits': landmark_idx + 1,
            'days_from_last_visit': current_visit['days_until_next_visit'],
            'death_in_90days': death_in_90days,
            'med_text': meds_text,
            'diag_text': diag_text,
            'proc_text': proc_text
        })

landmark_df = pd.DataFrame(landmark_rows)

# %%
landmark_df.head(10)
# Out:
#    subject_id  landmark_visit  age_at_landmark gender  num_total_visits  \
# 0    10000032               1               52      F                 1
# 1    10000032               2               52      F                 2
# 2    10000032               3               52      F                 3
# 3    10000032               4               52      F                 4
# 4    10000068               1               19      F                 1
# 5    10000084               1               72      M                 1
# 6    10000084               2               72      M                 2
# 7    10000108               1               25      M                 1
# 8    10000117               1               55      F                 1
# 9    10000117               2               57      F                 2
#
#    days_from_last_visit  death_in_90days  \
# 0                  50.0                1
# 1                  25.0                1
# 2                  11.0                1
# 3                  -1.0                1
# 4                  -1.0                0
# 5                  32.0                1
# 6                  -1.0                1
# 7                  -1.0                0
# 8                 672.0                0
# 9                  -1.0                0
#
#                                             med_text  \
# 0  Furosemide; Ipratropium Bromide Neb; Potassium...
# 1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 2  Furosemide; Ipratropium Bromide Neb; Potassium...
# 3  Furosemide; Ipratropium Bromide Neb; Potassium...
# 4
# 5  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 6  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 7
# 8               Heparin; Sodium Chloride 0.9%  Flush
# 9  Heparin; Sodium Chloride 0.9%  Flush Iso-Osmot...
#
#                                            diag_text  \
# 0  Portal hypertension; Other ascites; Cirrhosis ...
# 1  Portal hypertension; Other ascites; Cirrhosis ...
# 2  Portal hypertension; Other ascites; Cirrhosis ...
# 3  Portal hypertension; Other ascites; Cirrhosis ...
# 4                         Alcohol abuse, unspecified
# 5  Neurocognitive disorder with Lewy bodies; Deme...
# 6  Neurocognitive disorder with Lewy bodies; Deme...
# 7  Cellulitis and abscess of oral soft tissues; O...
# 8  Dysphagia, unspecified; Other specified sympto...
# 9  Dysphagia, unspecified; Other specified sympto...
#
#                                            proc_text
# 0                    Percutaneous abdominal drainage
# 1  Percutaneous abdominal drainage Percutaneous a...
# 2  Percutaneous abdominal drainage Percutaneous a...
# 3  Percutaneous abdominal drainage Percutaneous a...
# 4        Other nonoperative respiratory measurements
# 5
# 6
# 7
# 8
# 9   Reposition Left Upper Femur with Internal Fix...

# %%
# Convert gender explicitly into binary numeric values
landmark_df['gender_numeric'] = landmark_df['gender'].map({'F': 0, 'M': 1})
landmark_df.head(5)
# Out:
#    subject_id  landmark_visit  age_at_landmark gender  num_total_visits  \
# 0    10000032               1               52      F                 1
# 1    10000032               2               52      F                 2
# 2    10000032               3               52      F                 3
# 3    10000032               4               52      F                 4
# 4    10000068               1               19      F                 1
#
#    days_from_last_visit  death_in_90days  \
# 0                  50.0                1
# 1                  25.0                1
# 2                  11.0                1
# 3                  -1.0                1
# 4                  -1.0                0
#
#                                             med_text  \
# 0  Furosemide; Ipratropium Bromide Neb; Potassium...
# 1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 2  Furosemide; Ipratropium Bromide Neb; Potassium...
# 3  Furosemide; Ipratropium Bromide Neb; Potassium...
# 4
#
#                                            diag_text  \
# 0  Portal hypertension; Other ascites; Cirrhosis ...
# 1  Portal hypertension; Other ascites; Cirrhosis ...
# 2  Portal hypertension; Other ascites; Cirrhosis ...
# 3  Portal hypertension; Other ascites; Cirrhosis ...
# 4                         Alcohol abuse, unspecified
#
#                                            proc_text  gender_numeric
# 0                    Percutaneous abdominal drainage               0
# 1  Percutaneous abdominal drainage Percutaneous a...               0
# 2  Percutaneous abdominal drainage Percutaneous a...               0
# 3  Percutaneous abdominal drainage Percutaneous a...               0
# 4        Other nonoperative respiratory measurements               0

# %%
landmark_df.to_csv('landmark_df_2.csv', index=False, na_rep = 'Unknown')

# %%
# Let us check if they are equals
landmark_df_1 = pd.read_csv("landmark_df.csv")

# %%
landmark_df.equals(landmark_df_1)
# Out:
# False

# %%
landmark_df_1.iloc[44]
# Out:
# subject_id                                                            10001186
# landmark_visit                                                               1
# age_at_landmark                                                             46
# gender                                                                       F
# num_total_visits                                                             1
# death_in_90days                                                              0
# med_text                     Sodium Chloride 0.9%  Flush Ondansetron Guaife...
# diag_text                    Disruption of external operation (surgical) wo...
# proc_text                                               Removal of skull plate
# gender_numeric                                                               0
# days_since_previous_visit                                                 -1.0
# Name: 44, dtype: object

# %%
landmark_df.iloc[44]
# Out:
# subject_id                                                       10001186
# landmark_visit                                                          1
# age_at_landmark                                                        46
# gender                                                                  F
# num_total_visits                                                        1
# days_from_last_visit                                                 23.0
# death_in_90days                                                         0
# med_text                Sodium Chloride 0.9%  Flush; Ondansetron; Guai...
# diag_text               Disruption of external operation (surgical) wo...
# proc_text                                          Removal of skull plate
# gender_numeric                                                          0
# Name: 44, dtype: object

# %% [markdown]
# Still not equals. Something is missing...

# %%
# Ensure your DataFrame is sorted by patient and landmark_visit
landmark_df = landmark_df.sort_values(['subject_id', 'landmark_visit']).reset_index(drop=True)

# Function to perform transformation
def transform_to_past_variable(group):
    group = group.sort_values('landmark_visit').copy()
    # Shift the values down (future to past)
    group['days_since_last_visit'] = group['days_from_last_visit'].shift(1)
    # First landmark always has -1
    group['days_since_last_visit'].iloc[0] = -1
    return group

# Apply the transformation per patient
landmark_df = landmark_df.groupby('subject_id').apply(transform_to_past_variable).reset_index(drop=True)

# Drop the original future-looking column (optional but strongly recommended)
landmark_df.drop(columns=['days_from_last_visit'], inplace=True)

# Check the result clearly
print(landmark_df[['subject_id', 'landmark_visit', 'days_since_last_visit']].head(15))
# Out:
#     subject_id  landmark_visit  days_since_last_visit
# 0     10000032               1                   -1.0
# 1     10000032               2                   50.0
# 2     10000032               3                   25.0
# 3     10000032               4                   11.0
# 4     10000068               1                   -1.0
# 5     10000084               1                   -1.0
# 6     10000084               2                   32.0
# 7     10000108               1                   -1.0
# 8     10000117               1                   -1.0
# 9     10000117               2                  672.0
# 10    10000161               1                   -1.0
# 11    10000248               1                   -1.0
# 12    10000280               1                   -1.0
# 13    10000560               1                   -1.0
# 14    10000635               1                   -1.0

# %%
landmark_df = landmark_df.rename(columns={'days_since_last_visit':'days_since_previous_visit'})
landmark_df.head(10)
# Out:
#    subject_id  landmark_visit  age_at_landmark gender  num_total_visits  \
# 0    10000032               1               52      F                 1
# 1    10000032               2               52      F                 2
# 2    10000032               3               52      F                 3
# 3    10000032               4               52      F                 4
# 4    10000068               1               19      F                 1
# 5    10000084               1               72      M                 1
# 6    10000084               2               72      M                 2
# 7    10000108               1               25      M                 1
# 8    10000117               1               55      F                 1
# 9    10000117               2               57      F                 2
#
#    death_in_90days                                           med_text  \
# 0                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 1                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 2                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 3                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 4                0
# 5                1  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 6                1  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 7                0
# 8                0               Heparin; Sodium Chloride 0.9%  Flush
# 9                0  Heparin; Sodium Chloride 0.9%  Flush Iso-Osmot...
#
#                                            diag_text  \
# 0  Portal hypertension; Other ascites; Cirrhosis ...
# 1  Portal hypertension; Other ascites; Cirrhosis ...
# 2  Portal hypertension; Other ascites; Cirrhosis ...
# 3  Portal hypertension; Other ascites; Cirrhosis ...
# 4                         Alcohol abuse, unspecified
# 5  Neurocognitive disorder with Lewy bodies; Deme...
# 6  Neurocognitive disorder with Lewy bodies; Deme...
# 7  Cellulitis and abscess of oral soft tissues; O...
# 8  Dysphagia, unspecified; Other specified sympto...
# 9  Dysphagia, unspecified; Other specified sympto...
#
#                                            proc_text  gender_numeric  \
# 0                    Percutaneous abdominal drainage               0
# 1  Percutaneous abdominal drainage Percutaneous a...               0
# 2  Percutaneous abdominal drainage Percutaneous a...               0
# 3  Percutaneous abdominal drainage Percutaneous a...               0
# 4        Other nonoperative respiratory measurements               0
# 5                                                                  1
# 6                                                                  1
# 7                                                                  1
# 8                                                                  0
# 9   Reposition Left Upper Femur with Internal Fix...               0
#
#    days_since_previous_visit
# 0                       -1.0
# 1                       50.0
# 2                       25.0
# 3                       11.0
# 4                       -1.0
# 5                       -1.0
# 6                       32.0
# 7                       -1.0
# 8                       -1.0
# 9                      672.0

# %%
landmark_df.to_csv('landmark_df_2.csv', index=False, na_rep = 'Unknown')

# %%
landmark_df_2 = pd.read_csv('landmark_df_2.csv')

# %%
landmark_df_1.head(10)
# Out:
#    subject_id  landmark_visit  age_at_landmark gender  num_total_visits  \
# 0    10000032               1               52      F                 1
# 1    10000032               2               52      F                 2
# 2    10000032               3               52      F                 3
# 3    10000032               4               52      F                 4
# 4    10000068               1               19      F                 1
# 5    10000084               1               72      M                 1
# 6    10000084               2               72      M                 2
# 7    10000108               1               25      M                 1
# 8    10000117               1               55      F                 1
# 9    10000117               2               57      F                 2
#
#    death_in_90days                                           med_text  \
# 0                1  Furosemide Ipratropium Bromide Neb Potassium C...
# 1                1  Furosemide Ipratropium Bromide Neb Potassium C...
# 2                1  Furosemide Ipratropium Bromide Neb Potassium C...
# 3                1  Furosemide Ipratropium Bromide Neb Potassium C...
# 4                0                                            Unknown
# 5                1  Pramipexole Pravastatin rivastigmine Senna QUE...
# 6                1  Pramipexole Pravastatin rivastigmine Senna QUE...
# 7                0                                            Unknown
# 8                0                Heparin Sodium Chloride 0.9%  Flush
# 9                0  Heparin Sodium Chloride 0.9%  Flush Iso-Osmoti...
#
#                                            diag_text  \
# 0  Portal hypertension Other ascites Cirrhosis of...
# 1  Portal hypertension Other ascites Cirrhosis of...
# 2  Portal hypertension Other ascites Cirrhosis of...
# 3  Portal hypertension Other ascites Cirrhosis of...
# 4                         Alcohol abuse, unspecified
# 5  Neurocognitive disorder with Lewy bodies Demen...
# 6  Neurocognitive disorder with Lewy bodies Demen...
# 7  Cellulitis and abscess of oral soft tissues Ot...
# 8  Dysphagia, unspecified Other specified symptom...
# 9  Dysphagia, unspecified Other specified symptom...
#
#                                            proc_text  gender_numeric  \
# 0                    Percutaneous abdominal drainage               0
# 1  Percutaneous abdominal drainage Percutaneous a...               0
# 2  Percutaneous abdominal drainage Percutaneous a...               0
# 3  Percutaneous abdominal drainage Percutaneous a...               0
# 4        Other nonoperative respiratory measurements               0
# 5                                            Unknown               1
# 6                                                                  1
# 7                                            Unknown               1
# 8                                            Unknown               0
# 9   Reposition Left Upper Femur with Internal Fix...               0
#
#    days_since_previous_visit
# 0                       -1.0
# 1                       50.0
# 2                       25.0
# 3                       11.0
# 4                       -1.0
# 5                       -1.0
# 6                       32.0
# 7                       -1.0
# 8                       -1.0
# 9                      672.0

# %%
landmark_df_2.head(10)
# Out:
#    subject_id  landmark_visit  age_at_landmark gender  num_total_visits  \
# 0    10000032               1               52      F                 1
# 1    10000032               2               52      F                 2
# 2    10000032               3               52      F                 3
# 3    10000032               4               52      F                 4
# 4    10000068               1               19      F                 1
# 5    10000084               1               72      M                 1
# 6    10000084               2               72      M                 2
# 7    10000108               1               25      M                 1
# 8    10000117               1               55      F                 1
# 9    10000117               2               57      F                 2
#
#    death_in_90days                                           med_text  \
# 0                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 1                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 2                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 3                1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 4                0                                                NaN
# 5                1  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 6                1  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 7                0                                                NaN
# 8                0               Heparin; Sodium Chloride 0.9%  Flush
# 9                0  Heparin; Sodium Chloride 0.9%  Flush Iso-Osmot...
#
#                                            diag_text  \
# 0  Portal hypertension; Other ascites; Cirrhosis ...
# 1  Portal hypertension; Other ascites; Cirrhosis ...
# 2  Portal hypertension; Other ascites; Cirrhosis ...
# 3  Portal hypertension; Other ascites; Cirrhosis ...
# 4                         Alcohol abuse, unspecified
# 5  Neurocognitive disorder with Lewy bodies; Deme...
# 6  Neurocognitive disorder with Lewy bodies; Deme...
# 7  Cellulitis and abscess of oral soft tissues; O...
# 8  Dysphagia, unspecified; Other specified sympto...
# 9  Dysphagia, unspecified; Other specified sympto...
#
#                                            proc_text  gender_numeric  \
# 0                    Percutaneous abdominal drainage               0
# 1  Percutaneous abdominal drainage Percutaneous a...               0
# 2  Percutaneous abdominal drainage Percutaneous a...               0
# 3  Percutaneous abdominal drainage Percutaneous a...               0
# 4        Other nonoperative respiratory measurements               0
# 5                                                NaN               1
# 6                                                NaN               1
# 7                                                NaN               1
# 8                                                NaN               0
# 9   Reposition Left Upper Femur with Internal Fix...               0
#
#    days_since_previous_visit
# 0                       -1.0
# 1                       50.0
# 2                       25.0
# 3                       11.0
# 4                       -1.0
# 5                       -1.0
# 6                       32.0
# 7                       -1.0
# 8                       -1.0
# 9                      672.0

# %%
landmark_df_2.dtypes
landmark_df_2.proc_text[5]
# Out:
# nan

# %%
landmark_df_1.dtypes
landmark_df_1.proc_text[5]
# Out:
# 'Unknown'

# %%
landmark_df_2.to_csv('landmark_df_2.csv', index=False, na_rep = 'Unknown')

# %%
landmark_df_3 = pd.read_csv('landmark_df_2.csv')

# %%
landmark_df_3.head(20)
# Out:
#     subject_id  landmark_visit  age_at_landmark gender  num_total_visits  \
# 0     10000032               1               52      F                 1
# 1     10000032               2               52      F                 2
# 2     10000032               3               52      F                 3
# 3     10000032               4               52      F                 4
# 4     10000068               1               19      F                 1
# 5     10000084               1               72      M                 1
# 6     10000084               2               72      M                 2
# 7     10000108               1               25      M                 1
# 8     10000117               1               55      F                 1
# 9     10000117               2               57      F                 2
# 10    10000161               1               60      M                 1
# 11    10000248               1               34      M                 1
# 12    10000280               1               20      M                 1
# 13    10000560               1               53      F                 1
# 14    10000635               1               74      F                 1
# 15    10000635               2               81      F                 2
# 16    10000690               1               86      F                 1
# 17    10000690               2               86      F                 2
# 18    10000690               3               86      F                 3
# 19    10000690               4               88      F                 4
#
#     death_in_90days                                           med_text  \
# 0                 1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 1                 1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 2                 1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 3                 1  Furosemide; Ipratropium Bromide Neb; Potassium...
# 4                 0                                            Unknown
# 5                 1  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 6                 1  Pramipexole; Pravastatin; rivastigmine; Senna;...
# 7                 0                                            Unknown
# 8                 0               Heparin; Sodium Chloride 0.9%  Flush
# 9                 0  Heparin; Sodium Chloride 0.9%  Flush Iso-Osmot...
# 10                0                                            Unknown
# 11                0  OxycoDONE (Immediate Release) ; Acetaminophen;...
# 12                0                                            Unknown
# 13                0  Acetaminophen; Lorazepam; Metoclopramide; Onda...
# 14                0  Potassium Chloride; PNEUMOcoccal 23-valent pol...
# 15                0  Potassium Chloride; PNEUMOcoccal 23-valent pol...
# 16                1  Lisinopril; Furosemide; Metoprolol Succinate X...
# 17                1  Lisinopril; Furosemide; Metoprolol Succinate X...
# 18                1  Lisinopril; Furosemide; Metoprolol Succinate X...
# 19                1  Lisinopril; Furosemide; Metoprolol Succinate X...
#
#                                             diag_text  \
# 0   Portal hypertension; Other ascites; Cirrhosis ...
# 1   Portal hypertension; Other ascites; Cirrhosis ...
# 2   Portal hypertension; Other ascites; Cirrhosis ...
# 3   Portal hypertension; Other ascites; Cirrhosis ...
# 4                          Alcohol abuse, unspecified
# 5   Neurocognitive disorder with Lewy bodies; Deme...
# 6   Neurocognitive disorder with Lewy bodies; Deme...
# 7   Cellulitis and abscess of oral soft tissues; O...
# 8   Dysphagia, unspecified; Other specified sympto...
# 9   Dysphagia, unspecified; Other specified sympto...
# 10  Immune thrombocytopenic purpura; Headache, uns...
# 11  Contusion of abdominal wall; Contusion of face...
# 12                     Cellulitis and abscess of face
# 13  Malignant neoplasm of kidney, except pelvis; P...
# 14  Other specified cardiac dysrhythmias; Diabetes...
# 15  Other specified cardiac dysrhythmias; Diabetes...
# 16  Congestive heart failure, unspecified; Acute o...
# 17  Congestive heart failure, unspecified; Acute o...
# 18  Congestive heart failure, unspecified; Acute o...
# 19  Congestive heart failure, unspecified; Acute o...
#
#                                             proc_text  gender_numeric  \
# 0                     Percutaneous abdominal drainage               0
# 1   Percutaneous abdominal drainage Percutaneous a...               0
# 2   Percutaneous abdominal drainage Percutaneous a...               0
# 3   Percutaneous abdominal drainage Percutaneous a...               0
# 4         Other nonoperative respiratory measurements               0
# 5                                             Unknown               1
# 6                                             Unknown               1
# 7                                             Unknown               1
# 8                                             Unknown               0
# 9    Reposition Left Upper Femur with Internal Fix...               0
# 10                                            Unknown               1
# 11                                            Unknown               1
# 12        Other nonoperative respiratory measurements               1
# 13                                 Nephroureterectomy               0
# 14  Excision or destruction of other lesion or tis...               0
# 15  Excision or destruction of other lesion or tis...               0
# 16                                            Unknown               0
# 17                                            Unknown               0
# 18    Venous catheterization, not elsewhere classi...               0
# 19    Venous catheterization, not elsewhere classi...               0
#
#     days_since_previous_visit
# 0                        -1.0
# 1                        50.0
# 2                        25.0
# 3                        11.0
# 4                        -1.0
# 5                        -1.0
# 6                        32.0
# 7                        -1.0
# 8                        -1.0
# 9                       672.0
# 10                       -1.0
# 11                       -1.0
# 12                       -1.0
# 13                       -1.0
# 14                       -1.0
# 15                     2742.0
# 16                       -1.0
# 17                       71.0
# 18                       39.0
# 19                      442.0

# %%
landmark_df_3.equals(landmark_df_1)
# Out:
# False

# %% [markdown]
# Okay, so the code here it's the one that has been generated trough xgboost.ipynb. The Unknown have been creating saving two times the dataframe. First, creating NaN and then creating Unknown.

# %% [markdown]
# #### Why not all blank spaces are 'Unknown'?
# Let's take the 10000084 subject. In the second landmark visit we don't have anymore Unknown, but, rather, ''. We need to investigate further.
# Solved! See the code above, has already the solution.
