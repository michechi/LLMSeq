# %%
import pandas as pd

data = pd.read_csv('landmark_df.csv')

# %%
print(data.head(4)['med_text'][0])
# Out:
# Furosemide Ipratropium Bromide Neb Potassium Chloride Sodium Chloride 0.9%  Flush Raltegravir Spironolactone Acetaminophen Influenza Vaccine Quadrivalent Albuterol Inhaler Emtricitabine-Tenofovir (Truvada) Heparin Nicotine Patch

# %%
print(data.head(4)['med_text'][1])
# Out:
# Furosemide Ipratropium Bromide Neb Potassium Chloride Sodium Chloride 0.9%  Flush Raltegravir Spironolactone Acetaminophen Influenza Vaccine Quadrivalent Albuterol Inhaler Emtricitabine-Tenofovir (Truvada) Heparin Nicotine Patch Furosemide Rifaximin Sodium Chloride 0.9%  Flush Albuterol Inhaler Calcium Carbonate Acetaminophen Influenza Vaccine Quadrivalent Albumin 25% (12.5g / 50mL) Tiotropium Bromide Emtricitabine-Tenofovir (Truvada) Lactulose Raltegravir Heparin Sulfameth/Trimethoprim DS

# %%
print(data.head(4)['diag_text'][0])
# Out:
# Portal hypertension Other ascites Cirrhosis of liver without mention of alcohol Unspecified viral hepatitis C without hepatic coma Chronic airway obstruction, not elsewhere classified Bipolar disorder, unspecified Posttraumatic stress disorder Personal history of tobacco use

# %%
print(data.head(4)['diag_text'][1])
# Out:
# Portal hypertension Other ascites Cirrhosis of liver without mention of alcohol Unspecified viral hepatitis C without hepatic coma Chronic airway obstruction, not elsewhere classified Bipolar disorder, unspecified Posttraumatic stress disorder Personal history of tobacco use Unspecified viral hepatitis C with hepatic coma Other ascites Thrombocytopenia, unspecified Hyposmolality and/or hyponatremia Chronic airway obstruction, not elsewhere classified Cirrhosis of liver without mention of alcohol Asymptomatic human immunodeficiency virus [HIV] infection status Tobacco use disorder

# %%
print(data.head(4)['diag_text'][2])
# Out:
# Portal hypertension Other ascites Cirrhosis of liver without mention of alcohol Unspecified viral hepatitis C without hepatic coma Chronic airway obstruction, not elsewhere classified Bipolar disorder, unspecified Posttraumatic stress disorder Personal history of tobacco use Unspecified viral hepatitis C with hepatic coma Other ascites Thrombocytopenia, unspecified Hyposmolality and/or hyponatremia Chronic airway obstruction, not elsewhere classified Cirrhosis of liver without mention of alcohol Asymptomatic human immunodeficiency virus [HIV] infection status Tobacco use disorder Other iatrogenic hypotension Chronic hepatitis C with hepatic coma Cachexia Hyposmolality and/or hyponatremia Other ascites Hyperpotassemia Tobacco use disorder Asymptomatic human immunodeficiency virus [HIV] infection status Do not resuscitate status Other dependence on machines, supplemental oxygen Chronic airway obstruction, not elsewhere classified Bipolar disorder, unspecified Cirrhosis of liver without
# ...

# %%
set(data.head(4)['diag_text'][1]+ " " + data.head(4)['diag_text'][0])
# Out:
# {' ',
#  ',',
#  '/',
#  'A',
#  'B',
#  'C',
#  'H',
#  'I',
#  'O',
#  'P',
#  'T',
#  'U',
#  'V',
#  '[',
#  ']',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'h',
#  'i',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  'w',
#  'y'}
